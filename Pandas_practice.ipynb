# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['a','b','c'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      int64
#  1   b       3 non-null      int64
#  2   c       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0 bytes

# %%
df.describe()
# Out:
#          a    b    c
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df=pd.read_csv("Movies.csv")

# %%
df.to_parquet
# Out:
# <bound method DataFrame.to_parquet of                  Name    Language               Genre  Rating  \
# 0           Inception     English    Sci-Fi, Thriller     9.0
# 1            Parasite      Korean     Thriller, Drama     8.6
# 2     The Dark Knight     English       Action, Crime     9.1
# 3       Spirited Away    Japanese  Animation, Fantasy     8.9
# 4        Interstellar     English       Sci-Fi, Drama     8.7
# 5         City of God  Portuguese        Crime, Drama     8.6
# 6    Schindler’s List     English      Drama, History     9.0
# 7           Your Name    Japanese  Animation, Romance     8.5
# 8            3 Idiots       Hindi       Comedy, Drama     8.4
# 9  Gangs of Wasseypur       Hindi       Crime, Action     8.2
#
#                                               Review
# 0  A mind-bending thriller with stunning visuals ...
# 1  A brilliant social commentary wrapped in an in...
# 2  A gripping superhero film with an iconic perfo...
# ...

# %%
df
# Out:
#                  Name    Language               Genre  Rating  \
# 0           Inception     English    Sci-Fi, Thriller     9.0
# 1            Parasite      Korean     Thriller, Drama     8.6
# 2     The Dark Knight     English       Action, Crime     9.1
# 3       Spirited Away    Japanese  Animation, Fantasy     8.9
# 4        Interstellar     English       Sci-Fi, Drama     8.7
# 5         City of God  Portuguese        Crime, Drama     8.6
# 6    Schindler’s List     English      Drama, History     9.0
# 7           Your Name    Japanese  Animation, Romance     8.5
# 8            3 Idiots       Hindi       Comedy, Drama     8.4
# 9  Gangs of Wasseypur       Hindi       Crime, Action     8.2
#
#                                               Review
# 0  A mind-bending thriller with stunning visuals ...
# 1  A brilliant social commentary wrapped in an in...
# 2  A gripping superhero film with an iconic perfo...
# 3  A visually stunning and heartwarming tale fill...
# ...

# %%
df.head()
# Out:
#               Name  Language               Genre  Rating  \
# 0        Inception   English    Sci-Fi, Thriller     9.0
# 1         Parasite    Korean     Thriller, Drama     8.6
# 2  The Dark Knight   English       Action, Crime     9.1
# 3    Spirited Away  Japanese  Animation, Fantasy     8.9
# 4     Interstellar   English       Sci-Fi, Drama     8.7
#
#                                               Review
# 0  A mind-bending thriller with stunning visuals ...
# 1  A brilliant social commentary wrapped in an in...
# 2  A gripping superhero film with an iconic perfo...
# 3  A visually stunning and heartwarming tale fill...
# 4  A thought-provoking space epic with emotional ...

# %%
df.tail()
# Out:
#                  Name    Language               Genre  Rating  \
# 5         City of God  Portuguese        Crime, Drama     8.6
# 6    Schindler’s List     English      Drama, History     9.0
# 7           Your Name    Japanese  Animation, Romance     8.5
# 8            3 Idiots       Hindi       Comedy, Drama     8.4
# 9  Gangs of Wasseypur       Hindi       Crime, Action     8.2
#
#                                               Review
# 5  A raw and powerful depiction of life in the fa...
# 6  A deeply moving and haunting portrayal of the ...
# 7  A beautifully animated love story with an intr...
# 8  A heartwarming and inspiring take on education...
# 9  A gripping gangster saga with raw storytelling...

# %%
df.set_index(df.Name)
# Out:
#                                   Name    Language               Genre  \
# Name
# Inception                    Inception     English    Sci-Fi, Thriller
# Parasite                      Parasite      Korean     Thriller, Drama
# The Dark Knight        The Dark Knight     English       Action, Crime
# Spirited Away            Spirited Away    Japanese  Animation, Fantasy
# Interstellar              Interstellar     English       Sci-Fi, Drama
# City of God                City of God  Portuguese        Crime, Drama
# Schindler’s List      Schindler’s List     English      Drama, History
# Your Name                    Your Name    Japanese  Animation, Romance
# 3 Idiots                      3 Idiots       Hindi       Comedy, Drama
# Gangs of Wasseypur  Gangs of Wasseypur       Hindi       Crime, Action
#
#                     Rating                                             Review
# Name
# Inception              9.0  A mind-bending thriller with stunning visuals ...
# ...

# %%
df.reset_index()
# Out:
#    index                Name    Language               Genre  Rating  \
# 0      0           Inception     English    Sci-Fi, Thriller     9.0
# 1      1            Parasite      Korean     Thriller, Drama     8.6
# 2      2     The Dark Knight     English       Action, Crime     9.1
# 3      3       Spirited Away    Japanese  Animation, Fantasy     8.9
# 4      4        Interstellar     English       Sci-Fi, Drama     8.7
# 5      5         City of God  Portuguese        Crime, Drama     8.6
# 6      6    Schindler’s List     English      Drama, History     9.0
# 7      7           Your Name    Japanese  Animation, Romance     8.5
# 8      8            3 Idiots       Hindi       Comedy, Drama     8.4
# 9      9  Gangs of Wasseypur       Hindi       Crime, Action     8.2
#
#                                               Review
# 0  A mind-bending thriller with stunning visuals ...
# 1  A brilliant social commentary wrapped in an in...
# ...

# %%
df.iloc[3:7:1] #remember square bracket, takes start stop and step value.
# Out:
#                Name    Language               Genre  Rating  \
# 3     Spirited Away    Japanese  Animation, Fantasy     8.9
# 4      Interstellar     English       Sci-Fi, Drama     8.7
# 5       City of God  Portuguese        Crime, Drama     8.6
# 6  Schindler’s List     English      Drama, History     9.0
#
#                                               Review
# 3  A visually stunning and heartwarming tale fill...
# 4  A thought-provoking space epic with emotional ...
# 5  A raw and powerful depiction of life in the fa...
# 6  A deeply moving and haunting portrayal of the ...

# %%
a=df[(df.index<7)&(df.Rating>8.5)]  #combining multiple constraints.

# %%
a
# Out:
#                Name    Language               Genre  Rating  \
# 0         Inception     English    Sci-Fi, Thriller     9.0
# 1          Parasite      Korean     Thriller, Drama     8.6
# 2   The Dark Knight     English       Action, Crime     9.1
# 3     Spirited Away    Japanese  Animation, Fantasy     8.9
# 4      Interstellar     English       Sci-Fi, Drama     8.7
# 5       City of God  Portuguese        Crime, Drama     8.6
# 6  Schindler’s List     English      Drama, History     9.0
#
#                                               Review
# 0  A mind-bending thriller with stunning visuals ...
# 1  A brilliant social commentary wrapped in an in...
# 2  A gripping superhero film with an iconic perfo...
# 3  A visually stunning and heartwarming tale fill...
# 4  A thought-provoking space epic with emotional ...
# 5  A raw and powerful depiction of life in the fa...
# 6  A deeply moving and haunting portrayal of the ...

# %%
df.loc[7,"Rating"]=10 # one way to edit the data . 
# other way to edit is by at and iat method .

# %%
df
# Out:
#                  Name    Language               Genre  Rating  \
# 0           Inception     English    Sci-Fi, Thriller     9.0
# 1            Parasite      Korean     Thriller, Drama     8.6
# 2     The Dark Knight     English       Action, Crime     9.1
# 3       Spirited Away    Japanese  Animation, Fantasy     8.9
# 4        Interstellar     English       Sci-Fi, Drama     8.7
# 5         City of God  Portuguese        Crime, Drama     8.6
# 6    Schindler’s List     English      Drama, History     9.0
# 7           Your Name    Japanese  Animation, Romance    10.0
# 8            3 Idiots       Hindi       Comedy, Drama     8.4
# 9  Gangs of Wasseypur       Hindi       Crime, Action     8.2
#
#                                               Review
# 0  A mind-bending thriller with stunning visuals ...
# 1  A brilliant social commentary wrapped in an in...
# 2  A gripping superhero film with an iconic perfo...
# 3  A visually stunning and heartwarming tale fill...
# ...

# %%
df.at[0,"Rating"]=10 #only accesss single value for multiple values loc is used.

# %%
# if column head has more than one word call it by df["good boy"] df.good_boy wont work it only works with single values

# %%
# Sorting 
df.sort_values(["Name"]) 
df.sort_values("Name") # Both do the same job.  

# for sorting through multiple cloums add a list  to the method. fisrt sorts thorugh name then language.
df.sort_values(["Name","Language"])
# Out:
#                  Name    Language               Genre  Rating  \
# 8            3 Idiots       Hindi       Comedy, Drama     8.4
# 5         City of God  Portuguese        Crime, Drama     8.6
# 9  Gangs of Wasseypur       Hindi       Crime, Action     8.2
# 0           Inception     English    Sci-Fi, Thriller    10.0
# 4        Interstellar     English       Sci-Fi, Drama     8.7
# 1            Parasite      Korean     Thriller, Drama     8.6
# 6    Schindler’s List     English      Drama, History     9.0
# 3       Spirited Away    Japanese  Animation, Fantasy     8.9
# 2     The Dark Knight     English       Action, Crime     9.1
# 7           Your Name    Japanese  Animation, Romance    10.0
#
#                                               Review
# 8  A heartwarming and inspiring take on education...
# 5  A raw and powerful depiction of life in the fa...
# 9  A gripping gangster saga with raw storytelling...
# 0  A mind-bending thriller with stunning visuals ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      10 non-null     object
#  1   Language  10 non-null     object
#  2   Genre     10 non-null     object
#  3   Rating    10 non-null     float64
#  4   Review    10 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 532.0+ bytes

# %%
df.Name.info
# Out:
# <bound method Series.info of 0             Inception
# 1              Parasite
# 2       The Dark Knight
# 3         Spirited Away
# 4          Interstellar
# 5           City of God
# 6      Schindler’s List
# 7             Your Name
# 8              3 Idiots
# 9    Gangs of Wasseypur
# Name: Name, dtype: object>

# %%
df.Name.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10 entries, 0 to 9
# Series name: Name
# Non-Null Count  Dtype
# --------------  -----
# 10 non-null     object
# dtypes: object(1)
# memory usage: 212.0+ bytes

# %%
print(df.loc[1])
# Out:
# Name                                                 Parasite
# Language                                               Korean
# Genre                                         Thriller, Drama
# Rating                                                    8.6
# Review      A brilliant social commentary wrapped in an in...
# Name: 1, dtype: object

# %%
# filtering data  
import pandas as pd
ipl = pd.read_csv("deliveries.csv")

# %%
ipl.tail()
# Out:
#         match_id  inning           batting_team         bowling_team  over  \
# 260915   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260916   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260917   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
# 260918   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
# 260919   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
#
#         ball   batter         bowler non_striker  batsman_runs  extra_runs  \
# 260915     5  SS Iyer     AK Markram     VR Iyer             1           0
# 260916     6  VR Iyer     AK Markram     SS Iyer             1           0
# 260917     1  VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
# 260918     2  SS Iyer  Shahbaz Ahmed     VR Iyer             1           0
# 260919     3  VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
#
# ...

# %%
# ipl.loc[ipl.ball<5,"ball"]=5 changes all values to balls.
# same as ipl[ipl.ball<5]

# %%
ipl
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
print("hello")
# Out:
# hello

# %%
 #how to print the data if any perticular column contaisn a perticular word 
# through str.contains  
# case= False does not check case
 ipl[ipl.batting_team.str.contains("Kolkata")]
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
ipl[ipl.match_id.int.contains(33)] # no int .contais  only possible with string.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_49400\3226456300.py in ?()
# ----> 1 ipl[ipl.match_id.int.contains(33)] # no int .contais  only possible with string.
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'int'

# %%
# what does query method do.net

# %%
# adding removing columns . 
ipl["country"]="India"

# %%
ipl
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
# np.where ("add statement" , what to do if true, what to do if false) 
#coffee["new price"] = cofee.where["cofee[name]=="espresso",89,100)

# %%
# dropping a column  
ipl.drop(columns=['country']) # for permamnet dropping use inplace = True.
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
ipl.drop(3) # drops a row.
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 5         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
iplnew=ipl #changes to one will change both as location is same.

# %%
iplnew["State"]="odisha"

# %%
iplnew
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
ipl
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
iplnew = ipl.copy() # now different

# %%
#coffee=cofee["column1',"column 2"] will drop all columns except column 1 and 2

# %%
ipl.inning.rename("goodboy",inplace=True)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 260915    2
# 260916    2
# 260917    2
# 260918    2
# 260919    2
# Name: goodboy, Length: 260920, dtype: int64

# %%
ipl.goodboy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_49400\2532288797.py in ?()
# ----> 1 ipl.goodboy()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'goodboy'

# %%
ipl["random"]=ipl.over*ipl.ball #operations on different rows

# %%
print(ipl.over*ipl.ball)
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 260915    45
# 260916    54
# 260917    10
# 260918    20
# 260919    30
# Length: 260920, dtype: int64

# %%
#what does datetime do.

# %%
#apply method

# %%
#renaming a column 
ipl=ipl.rename(columns={'inning':'innings'})

# %%
ipl
# Out:
#         match_id  innings           batting_team                 bowling_team  \
# 0         335982        1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982        1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982        1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982        1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982        1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...      ...                    ...                          ...
# 260915   1426312        2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312        2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312        2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312        2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312        2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
#merging and concatenating data.z

ipl["batting_team"]=ipl["batting_team"].str.split(" ").str[0]

# %%
ipl
# Out:
#         match_id  innings batting_team                 bowling_team  over  \
# 0         335982        1      Kolkata  Royal Challengers Bangalore     0
# 1         335982        1      Kolkata  Royal Challengers Bangalore     0
# 2         335982        1      Kolkata  Royal Challengers Bangalore     0
# 3         335982        1      Kolkata  Royal Challengers Bangalore     0
# 4         335982        1      Kolkata  Royal Challengers Bangalore     0
# ...          ...      ...          ...                          ...   ...
# 260915   1426312        2      Kolkata          Sunrisers Hyderabad     9
# 260916   1426312        2      Kolkata          Sunrisers Hyderabad     9
# 260917   1426312        2      Kolkata          Sunrisers Hyderabad    10
# 260918   1426312        2      Kolkata          Sunrisers Hyderabad    10
# 260919   1426312        2      Kolkata          Sunrisers Hyderabad    10
#
#         ball       batter         bowler  non_striker  batsman_runs  \
# ...

# %%
str[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 str[1]
#
# TypeError: type 'str' is not subscriptable

# %%
ipl["good team"]=ipl["innings"].apply(lambda x: 'Short' if x<3 else ('avg'))

# %%
ipl
# Out:
#         match_id  innings batting_team                 bowling_team  over  \
# 0         335982        1      Kolkata  Royal Challengers Bangalore     0
# 1         335982        1      Kolkata  Royal Challengers Bangalore     0
# 2         335982        1      Kolkata  Royal Challengers Bangalore     0
# 3         335982        1      Kolkata  Royal Challengers Bangalore     0
# 4         335982        1      Kolkata  Royal Challengers Bangalore     0
# ...          ...      ...          ...                          ...   ...
# 260915   1426312        2      Kolkata          Sunrisers Hyderabad     9
# 260916   1426312        2      Kolkata          Sunrisers Hyderabad     9
# 260917   1426312        2      Kolkata          Sunrisers Hyderabad    10
# 260918   1426312        2      Kolkata          Sunrisers Hyderabad    10
# 260919   1426312        2      Kolkata          Sunrisers Hyderabad    10
#
#         ball       batter         bowler  non_striker  batsman_runs  ...  \
# ...

# %%
def catg(row): 
    if ((row["innings"]<5) & (row["ball"]<2)) : 
       return "good"
    else : 
       return "bad"

ipl["whatboy"]=ipl.apply(catg,axis=1) #axis =1 required to set rows.

# %%
ipl
# Out:
#         match_id  innings batting_team                 bowling_team  over  \
# 0         335982        1      Kolkata  Royal Challengers Bangalore     0
# 1         335982        1      Kolkata  Royal Challengers Bangalore     0
# 2         335982        1      Kolkata  Royal Challengers Bangalore     0
# 3         335982        1      Kolkata  Royal Challengers Bangalore     0
# 4         335982        1      Kolkata  Royal Challengers Bangalore     0
# ...          ...      ...          ...                          ...   ...
# 260915   1426312        2      Kolkata          Sunrisers Hyderabad     9
# 260916   1426312        2      Kolkata          Sunrisers Hyderabad     9
# 260917   1426312        2      Kolkata          Sunrisers Hyderabad    10
# 260918   1426312        2      Kolkata          Sunrisers Hyderabad    10
# 260919   1426312        2      Kolkata          Sunrisers Hyderabad    10
#
#         ball       batter         bowler  non_striker  batsman_runs  ...  \
# ...

# %%
# handling none values.

# %%
a=ipl.groupby("batting_team")

# %%
a["total_runs"].sum()

# %%
ipl["total_runs_sum"]=0

# %%
ipl["total_runs_sum"]=ipl["total_runs_sum"]=+1

# %%
ipl

# %%
a=ipl["batting_team"].unique() 
b

for i in a: 
    
        ipl.loc(ipl["batting_team"]==i).total_runs_sum= ipl.loc(["batting_team"]==i).total_runs_sum+1

# %%
for i in a : 
    b=ipl[ipl.batting_team==i]
     
    b.total_runs_sum=b.total_runs_sum+1

# %%
ipl

# %%
print(a)

# %%
for  i in ipl.batting_team:
    ipl.loc[ipl['batting_team'] == i, 'total_runs_sum'] = ipl.loc[ipl['batting_team'] == i, 'total_runs_sum'] + 1

# %%
ipl
# Out:
#         match_id  innings batting_team                 bowling_team  over  \
# 0         335982        1      Kolkata  Royal Challengers Bangalore     0
# 1         335982        1      Kolkata  Royal Challengers Bangalore     0
# 2         335982        1      Kolkata  Royal Challengers Bangalore     0
# 3         335982        1      Kolkata  Royal Challengers Bangalore     0
# 4         335982        1      Kolkata  Royal Challengers Bangalore     0
# ...          ...      ...          ...                          ...   ...
# 260915   1426312        2      Kolkata          Sunrisers Hyderabad     9
# 260916   1426312        2      Kolkata          Sunrisers Hyderabad     9
# 260917   1426312        2      Kolkata          Sunrisers Hyderabad    10
# 260918   1426312        2      Kolkata          Sunrisers Hyderabad    10
# 260919   1426312        2      Kolkata          Sunrisers Hyderabad    10
#
#         ball       batter         bowler  non_striker  batsman_runs  ...  \
# ...

# %%
ipl
# Out:
#         match_id  innings batting_team                 bowling_team  over  \
# 0         335982        1      Kolkata  Royal Challengers Bangalore     0
# 1         335982        1      Kolkata  Royal Challengers Bangalore     0
# 2         335982        1      Kolkata  Royal Challengers Bangalore     0
# 3         335982        1      Kolkata  Royal Challengers Bangalore     0
# 4         335982        1      Kolkata  Royal Challengers Bangalore     0
# ...          ...      ...          ...                          ...   ...
# 260915   1426312        2      Kolkata          Sunrisers Hyderabad     9
# 260916   1426312        2      Kolkata          Sunrisers Hyderabad     9
# 260917   1426312        2      Kolkata          Sunrisers Hyderabad    10
# 260918   1426312        2      Kolkata          Sunrisers Hyderabad    10
# 260919   1426312        2      Kolkata          Sunrisers Hyderabad    10
#
#         ball       batter         bowler  non_striker  batsman_runs  ...  \
# ...
